# %%
elif iOrR == "remove":while True:print("Purge files after removing? (Y/N)")choice = input().upper()if choice == "Y":os.system("sudo apt-get    -- purge " + iOrR + " " + packages)breakelif choice == "N":os.system("sudo apt-get " + iOrR + " " + packages)breakos.system("sudo apt autoremove")
# Out:
#   Cell In[1], line 1
#     elif iOrR == "remove":while True:print("Purge files after removing? (Y/N)")choice = input().upper()if choice == "Y":os.system("sudo apt-get    -- purge " + iOrR + " " + packages)breakelif choice == "N":os.system("sudo apt-get " + iOrR + " " + packages)breakos.system("sudo apt autoremove")
#     ^
# SyntaxError: invalid syntax

# %%
elif ioR == "remove":
    while True:
        print("Purge files after removing? (Y/N)")
        choice = input().upper()
        if choice == "Y":
            os.system("sudo apt-get --purge " + ioR + " " + packages)
            break
        elif choice == "N":
            os.system("sudo apt-get " + ioR + " " + packages)
            break
    os.system("sudo apt autoremove")
# Out:
#   Cell In[2], line 1
#     elif ioR == "remove":
#     ^
# SyntaxError: invalid syntax

# %%
if ioR == "install":
    os.system("sudo apt-get install " + packages)

elif ioR == "remove":
    while True:
        print("Purge files after removing? (Y/N)")
        choice = input().upper()

        if choice == "Y":
            os.system("sudo apt-get --purge " + ioR + " " + packages)
            break

        elif choice == "N":
            os.system("sudo apt-get " + ioR + " " + packages)
            break

    os.system("sudo apt autoremove")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 if ioR == "install":
#       2     os.system("sudo apt-get install " + packages)
#       4 elif ioR == "remove":
#
# NameError: name 'ioR' is not defined

# %%
import subprocess
elif ioR == "remove":
    while True:
        print("Purge files after removing? (Y/N)")
        choice = input().upper()
        if choice == "Y":
            subprocess.run(["sudo", "apt-get", "--purge", ioR, packages])
            break
        elif choice == "N":
            subprocess.run(["sudo", "apt-get", ioR, packages])
            break
    subprocess.run(["sudo", "apt", "autoremove"])
# Out:
#   Cell In[5], line 2
#     elif ioR == "remove":
#     ^
# SyntaxError: invalid syntax

# %%
import subprocess

# operación a realizar
ioR = input("Enter operation (install/remove): ").lower()

# paquetes por defecto
defaultPackages = "vim curl wget"

print("Enter a list of packages to install")
print("The list should be separated by spaces, for example:")
print(" package1 package2 package3")
print("Otherwise, input 'default' to " + ioR + " the default packages listed in this program")

packages = input().lower()

if packages == "default":
    packages = defaultPackages

# convertir paquetes a lista
package_list = packages.split()

if ioR == "install":
    subprocess.run(["sudo", "apt-get", "install"] + package_list)

elif ioR == "remove":
    while True:
        print("Purge files after removing? (Y/N)")
        choice = input().upper()

        if choice == "Y":
            subprocess.run(["sudo", "apt-get", "--purge"] + package_list)
            break

        elif choice == "N":
            subprocess.run(["sudo", "apt-get", "remove"] + package_list)
            break

    subprocess.run(["sudo", "apt", "autoremove"])

else:
    print("Invalid option")
# Out:
# Enter a list of packages to install
# The list should be separated by spaces, for example:
#  package1 package2 package3
# Otherwise, input 'default' to remove the default packages listed in this program
# Purge files after removing? (Y/N)
# Purge files after removing? (Y/N)
# Purge files after removing? (Y/N)
# Purge files after removing? (Y/N)
# Reading package lists...
# Building dependency tree...
# Reading state information...
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
